# %% [markdown]
# <a href="https://colab.research.google.com/github/sarvesh35ss/DAA1/blob/main/Unit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def interpolation_search(arr, target):
    """
    Interpolation Search Algorithm
    Time Complexity: O(log log n) average, O(n) worst case
    Space Complexity: O(1)
    """
    low, high = 0, len(arr) - 1
    comparisons = 0

    while low <= high and arr[low] <= target <= arr[high]:
        comparisons += 1
        if low == high:
            if arr[low] == target:
                return low, comparisons
            return -1, comparisons

        # Avoid division by zero if arr[high] == arr[low]
        if arr[high] == arr[low]:
            if arr[low] == target:
                return low, comparisons
            return -1, comparisons

        # Interpolation formula
        pos = low + int(((target - arr[low]) * (high - low))
                        / (arr[high] - arr[low]))

        if arr[pos] == target:
            return pos, comparisons
        elif arr[pos] < target:
            low = pos + 1
        else:
            high = pos - 1

    return -1, comparisons

def binary_search(arr, target):
    """Binary Search for comparison"""
    low, high = 0, len(arr) - 1
    comparisons = 0
    while low <= high:
        comparisons += 1
        mid = (low + high) // 2
        if arr[mid] == target:
            return mid, comparisons
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1, comparisons

def performance_analysis():
    sizes = [1000, 5000, 10000, 50000, 100000]
    results = []

    for size in sizes:
        arr = sorted(random.sample(range(size * 10), size))
        target = arr[random.randint(0, size - 1)]

        # Interpolation Search timing
        start = time.perf_counter()
        for _ in range(100):
            idx_is, comp_is = interpolation_search(arr, target)
        is_time = (time.perf_counter() - start) / 100 * 1000

        # Binary Search timing
        start = time.perf_counter()
        for _ in range(100):
            idx_bs, comp_bs = binary_search(arr, target)
        bs_time = (time.perf_counter() - start) / 100 * 1000

        results.append({
            'Size': size,
            'IS Time(ms)': is_time,
            'BS Time(ms)': bs_time,
            'IS Comparisons': comp_is,
            'BS Comparisons': comp_bs
        })
    return pd.DataFrame(results)

# --- Main ---
arr = [2, 5, 10, 15, 23, 35, 48, 60, 75, 90, 105, 120]
target = 35
idx, comps = interpolation_search(arr, target)
print(f"Array: {arr}")
print(f"Searching for: {target}")
print(f"Found at index: {idx}, Comparisons: {comps}")
print()

performance_df = performance_analysis()
print("Performance Analysis Results:")
display(performance_df)
# Out:
# Array: [2, 5, 10, 15, 23, 35, 48, 60, 75, 90, 105, 120]
# Searching for: 35
# Found at index: 5, Comparisons: 3
#
#       Size    IS Time(ms)    BS Time(ms)   IS Comparisons   BS Comparisons
# ---------------------------------------------------------------------------
#       1000         0.0009         0.0014                2               10
#       5000         0.0024         0.0057                5                9
#      10000         0.0014         0.0021                3               13
#      50000         0.0014         0.0027                3               16
#     100000         0.0022         0.0030                4               16

# %% [markdown]
# ## Performance Visualization: Time Comparison

# %%
# Plotting Time Comparison
plt.figure(figsize=(12, 6))
performance_df[['Size', 'IS Time(ms)', 'BS Time(ms)']].set_index('Size').plot(kind='bar', figsize=(12, 6))
plt.title('Interpolation Search vs. Binary Search: Time Comparison')
plt.xlabel('Array Size')
plt.ylabel('Time (milliseconds)')
plt.xticks(rotation=45)
plt.legend(['Interpolation Search Time', 'Binary Search Time'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Performance Visualization: Comparison Count

# %%
# Plotting Comparison Count
plt.figure(figsize=(12, 6))
performance_df[['Size', 'IS Comparisons', 'BS Comparisons']].set_index('Size').plot(kind='bar', figsize=(12, 6))
plt.title('Interpolation Search vs. Binary Search: Comparison Count')
plt.xlabel('Array Size')
plt.ylabel('Number of Comparisons (Probes)')
plt.xticks(rotation=45)
plt.legend(['Interpolation Search Comparisons', 'Binary Search Comparisons'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Student Roll Number Search Comparison
#
# Let's apply the Interpolation Search and Binary Search to a sorted array of student roll numbers (1 to 10000) and observe the number of comparisons (probes) for a given roll number.

# %% [markdown]
# ## General Performance Analysis
#
# The following table shows a general performance comparison between Interpolation Search and Binary Search across different array sizes, including time taken and the number of comparisons (probes).
